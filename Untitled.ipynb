# %%
import os

# %%
os.chdir('E:\\min\\Tokyo_tech_exchange\\NER')

# %%
NE = ['ne_dat', 'ne_loc', 'ne_mea', 'ne_org', 'ne_oth', 'ne_per', 'ne_tim']
cnt = {}
for i in NE:
    cnt[i] = 0

# %%
for (root,dirs,files) in os.walk('NE_20110823', topdown=True):
#     print(root)
#     print(dirs)
#     print(files)
    if len(dirs) == 0 and len(files) == 0:
        print("going to remove: " + root)
        os.rmdir(root)
    if len(files) != 0:
        try:
            cnt[root.split('\\')[-1]] = cnt[root.split('\\')[-1]] + len(files)
        except:
            cnt['ne_' + files[0].split('-')[-1].split('_')[1]] = cnt['ne_' + files[0].split('-')[-1].split('_')[1]] + len(files)
    print('------------------------------------------')
print(cnt)
# Out:
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ...

# %%
from pythainlp import word_tokenize
#import tensorflow
#import deepcut

# %%
from keras.models import Model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-31-b0ea6224d6fd> in <module>
# ----> 1 from keras.models import Model
#
# ModuleNotFoundError: No module named 'keras.models'

# %%
print(word_tokenize('ฉันกินข้าว', engine ='deepcut'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-d9b66bc4beae> in <module>
# ----> 1 print(word_tokenize('ฉันกินข้าว', engine ='deepcut'))
#
# ~\Anaconda3\envs\augmentation\lib\site-packages\pythainlp\tokenize\__init__.py in word_tokenize(text, custom_dict, engine, keep_whitespace)
#      61         segments = segment(text, custom_dict)
#      62     elif engine == "deepcut":  # deepcut can optionally use dictionary
# ---> 63         from .deepcut import segment
#      64
#      65         if custom_dict:
#
# ~\Anaconda3\envs\augmentation\lib\site-packages\pythainlp\tokenize\deepcut.py in <module>
#       6 from typing import List, Union
#       7
# ----> 8 import deepcut
#       9
#      10 from marisa_trie import Trie
#
# ModuleNotFoundError: No module named 'deepcut'
